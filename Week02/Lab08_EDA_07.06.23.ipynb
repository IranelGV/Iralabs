# %% [markdown]
# ## Activity 3 (Wednesday)
# As a reminder the objective of this study is to predict the total claim amount of a customer and study/investigate the impact of the factors (input features) on the target variable(total claim amount). That means in your exploratory data analysis, you have to look for patterns in this data that show interesting relationships among the input features as well as with relation to the target feature.
#
# Get the numeric data into a dataframe called numerical and categorical columns in a dataframe called categorical. (You can use "np.number" and "object" to select the numerical data types and categorical data types respectively)
# Now we will try to check the normality of the numerical variables visually
# Use the Seaborn library to construct distribution plots for the numerical variables
# Use the Matplotlib library to construct histograms.
#
#
# Do the distributions for different numerical variables look like a normal distribution?
# For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.
# Plot the Correlation Heatmap.
# (Optional): Drop one of the two features that show a high correlation between them (greater than 0.9). If there is no pair of features that have a high correlation, then do not drop any features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Data_creaned_by_teachers.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %% [markdown]
# ## Function: df.select_dtypes

# %%
numerical_df = df.select_dtypes(include=[np.number])
categorical_df = df.select_dtypes(include=['object'])

# %%
numerical_df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
categorical_df
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ### Now we will try to check the normality of the numerical variables visually Use the Seaborn library to construct distribution plots for the numerical variables Use the Matplotlib library to construct histograms.

# %% [markdown]
# ### customer_lifetime_value

# %%
sns.displot(df.customer_lifetime_value)

# %% [markdown]
# ### Income

# %%
sns.displot(df.income)

# %% [markdown]
# ### monthly_premium_auto

# %%
sns.displot(df.monthly_premium_auto)

# %% [markdown]
# ### months_since_last_claim

# %%
sns.displot(df.months_since_last_claim)

# %% [markdown]
# ### months_since_policy_inception

# %%
sns.displot(df.months_since_policy_inception)

# %% [markdown]
# ### number_of_open_complaints

# %%
sns.displot(df.number_of_open_complaints)

# %% [markdown]
# ### number_of_policies

# %%
sns.displot(df.number_of_policies)

# %% [markdown]
# ### Use the Matplotlib library to construct histograms

# %% [markdown]
# ### customer_lifetime_value

# %%
plt.hist(df['customer_lifetime_value'], bins=10)
plt.xlabel('customer_lifetime_value')
plt.ylabel('Values')
plt.title('Histogram customer_lifetime_value')
plt.show()

# %% [markdown]
# ### Income

# %%
plt.hist(df['income'], bins=10)
plt.xlabel('income')
plt.ylabel('Values')
plt.title('Histogram Income')
plt.show()

# %% [markdown]
# ### monthly_premium_auto

# %%
plt.hist(df['monthly_premium_auto'], bins=10)
plt.xlabel('monthly_premium_auto')
plt.ylabel('Values')
plt.title('Histogram monthly_premium_auto')
plt.show()

# %% [markdown]
# ### months_since_last_claim

# %%
plt.hist(df['months_since_last_claim'], bins=10)
plt.xlabel('months_since_last_claim')
plt.ylabel('Values')
plt.title('Histogram months_since_last_claim')
plt.show()

# %% [markdown]
# ### months_since_policy_inception

# %%
plt.hist(df['months_since_policy_inception'], bins=10)
plt.xlabel('months_since_policy_inception')
plt.ylabel('Values')
plt.title('Histogram months_since_policy_inception')
plt.show()

# %% [markdown]
# ### number_of_open_complaints

# %%
plt.hist(df['number_of_open_complaints'], bins=10)
plt.xlabel('number_of_open_complaints')
plt.ylabel('Values')
plt.title('Histogram number_of_open_complaints')
plt.show()

# %% [markdown]
# ### number_of_policies

# %%
plt.hist(df['number_of_policies'], bins=10)
plt.xlabel('number_of_policies')
plt.ylabel('Values')
plt.title('Histogram number_of_policies')
plt.show()

# %% [markdown]
# ### For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.
#
#
# ### Scatter Plot

# %%
months_since_policy_inception

# %%
plt.scatter(df['customer_lifetime_value'], df['income'])
plt.xlabel('customer_lifetime_value')
plt.ylabel('income')
plt.title('customer_lifetime_value inception vs income')
plt.show()

# %%
fig=plt.figure(figsize=(8,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
numerical_df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %% [markdown]
# Correlation between the input factors: Open complaints and customer value?

# %%
numerical_columns = numerical_df.columns

# %%
numerical_columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# Do the distributions for different numerical variables look like a normal distribution?
# For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.
