# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# Objective:
# - Combine and integrate data from multiple sources using merging, concatenating, or joining techniques to generate more comprehensive and meaningful datasets for analysis.
# - Modify the structure of data by pivoting, stacking/unstacking, or melting dataframes, enabling them to efficiently explore and analyze complex datasets.

# %% [markdown]
# # Challenge 1: Combining Data

# %% [markdown]
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv

# %% [markdown]
# Perform data cleaning and formatting using the main cleaning and formatting function created in the previous lab to clean and format the data.

# %% [markdown]
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %% [markdown]
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here

import pandas as pd
import numpy as np

# %%
df01=pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")

# %%
df01
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
columns_df01=df01.columns

# %%
columns_df01
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df02=pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")

# %%
df02
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
columns_df02=df02.columns

# %%
columns_df02
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df03=pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
df03
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
columns_df03=df03.columns

# %%
columns_df03
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %% [markdown]
# ### Renaming columns

# %%
def rename_columns(df):
    df.rename(columns= {"ST":"State", "GENDER": "gender"},inplace=True )
    return df

# %%
rename_columns(df01)
# Out:
#      Customer       State gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
rename_columns(df02)
# Out:
#     Customer       State gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
rename_columns(df03)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
lower_case_column_names(df01)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
lower_case_column_names(df02)
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
lower_case_column_names(df03)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %% [markdown]
# ### 👉Concatenating

# %%
customer_data = pd.concat([df01, df02, df03], ignore_index=True)

# %%
customer_data
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
columns_cd= customer_data.columns

# %%
columns_cd
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %% [markdown]
# ##### Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %%
shape_df01= df01.shape[::]

# %%
shape_df01
# Out:
# (4008, 11)

# %%
shape_df02= df02.shape[::]

# %%
shape_df02
# Out:
# (996, 11)

# %%
shape_df03= df03.shape[::]

# %%
shape_df03
# Out:
# (7070, 11)

# %%
customer_shape=customer_data.shape[::]

# %%
customer_shape
# Out:
# (12074, 11)

# %%
# Your code goes here
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.0+ MB

# %%
customer_data["customer lifetime value"] = customer_data["customer lifetime value"].apply(lambda x: x.replace("%","") if type(x)== str else x)

# %%
customer_data["customer lifetime value"] = customer_data["customer lifetime value"].astype(dtype ="float64")

# %%
customer_data["number of open complaints"] = customer_data["number of open complaints"].apply(lambda x: x.split("/")[1]  if type(x)==str else x)

# %%
customer_data["number of open complaints"] = customer_data["number of open complaints"].astype(dtype = "float64")

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   float64
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   float64
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Cleaning invalid Values

# %% [markdown]
# ### Gender

# %%
customer_data.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'Male'
    elif x in ['F', 'female',"Femal"]:
        return 'Female'
    else:
        return np.nan

# %%
customer_data['gender'] = list(map(clean_gender, customer_data['gender']))

# %%
customer_data.gender.value_counts()
# Out:
# Female    4607
# Male      4408
# Name: gender, dtype: int64

# %% [markdown]
# ### State

# %% [markdown]
# ### Education

# %% [markdown]
# ### Identify how many null values each column has

# %%
column_null_counts = customer_data.isnull().sum()

# %%
column_null_counts
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# customer lifetime value      2944
# income                       2937
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %% [markdown]
# ### Cleaning null values

# %%
customer_data = pd.DataFrame(round(customer_data.isna().sum()/len(customer_data ),4)*100)
customer_data = customer_data.reset_index()
customer_data.columns = ['header_name', 'percent_nulls']

# %%
customer_data
# Out:
#                   header_name  percent_nulls
# 0                    customer          24.32
# 1                       state          24.32
# 2                      gender          25.34
# 3                   education          24.32
# 4     customer lifetime value          24.38
# 5                      income          24.32
# 6        monthly premium auto          24.32
# 7   number of open complaints          24.32
# 8                 policy type          24.32
# 9               vehicle class          24.32
# 10         total claim amount          24.32

# %% [markdown]
# I will use the fillna() function in pandas to fill null values or dropna() function to drop null values.

# %% [markdown]
# **Dropna()  drop_duplicates()**

# %%
def remove_dups(x):
    x.drop_duplicates(subset = "customer",ignore_index = True, inplace=True)
    return x

# %%
remove_dups(customer_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49908\728623143.py in <module>
# ----> 1 remove_dups(customer_data)
#
# ~\AppData\Local\Temp\ipykernel_49908\85914418.py in remove_dups(x)
#       1 def remove_dups(x):
# ----> 2     x.drop_duplicates(subset = "customer",ignore_index = True, inplace=True)
#       3     return x
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6123         inplace = validate_bool_kwarg(inplace, "inplace")
#    6124         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# ...

# %% [markdown]
# ## Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %% [markdown]
# ## Exercise 1: Clean and Format the Data

# %% [markdown]
# While the dataset has been partially cleaned and formatted, we still need to perform several data cleaning tasks. Specifically, we need to standardize the column names, clean null values, convert the effective_to_date column to datetime, and extract the months from the dataset and store them in a separate column.
#
# To accomplish these tasks, we will use the functions created in the previous step to standardize the column names and deal with null values, and then we will apply additional functions to convert the effective_to_date column to datetime and extract the months.
#
# Save the clean dataset into a csv file.

# %%
marketing_customer = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv")

# %%
marketing_customer
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
marketing_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
columns_df= marketing_customer.columns

# %%
columns_df
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %% [markdown]
# ### Column names

# %%
def rename_columns(df):
    df.rename(columns= {"Unnamed: 0":"Index"},inplace=True )
    return df

# %%
rename_columns(marketing_customer)
# Out:
#        Index Customer       State  Customer Lifetime Value Response  Coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877         NaN              6857.519928      NaN     Basic
#
# ...

# %% [markdown]
# ### Lower case

# %%
def lower_case_column_names(df):
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
lower_case_column_names(marketing_customer)
# Out:
#        index customer       state  customer lifetime value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877         NaN              6857.519928      NaN     Basic
#
# ...

# %%
columns_df
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
marketing_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   index                          10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer lifetime value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective to date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location code                  10910 non-null  object
# ...

# %% [markdown]
# ### Changing my columns

# %%
def unique_values(df):
    df.columns = list(map(lambda x: x.replace(" ","_") if type(x)==str else x , df.columns ))
    return df.columns

# %%
unique_values(marketing_customer)
# Out:
# Index(['header_name', 'percent_nulls'], dtype='object')

# %% [markdown]
# ### Unique Values

# %%
def get_unique_values(df):
    unique_values = {}
    
    for column in df.columns:
        unique_values[column] = df[column].unique()
    
    return unique_values

# %% [markdown]
# ### Clean null values

# %%
#marketing_customer = pd.DataFrame(round(marketing_customer.isna().sum()/len(marketing_customer),4)*100)
#marketing_customer = marketing_customer.reset_index()
#marketing_customer.columns = ['header_name', 'percent_nulls']

# %%
marketing_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   header_name    26 non-null     object
#  1   percent_nulls  26 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 544.0+ bytes

# %%
#fill_nulls_mean= df.fillna(mean_float, inplace=True)

# %%
mode_state = marketing_customer["state"].mode().values[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
fillup_state=marketing_customer['state'].fillna(mode_state, inplace=True)

# %%
def fill_nulls_values(df):
    
    #float_columns = df.select_dtypes(include=['float64'])
    
    
    float_columns = df.select_dtypes(include=[np.float])
    mean_float = float_columns.mean()
    
    
    fill_nulls_mean= df.fillna(mean_float, inplace=True)
    
    return fill_nulls_mean

# %%
fill_nulls_values(marketing_customer)

# %%
marketing_customer.isna().sum()

# %%
marketing_customer = pd.DataFrame(round(marketing_customer.isna().sum()/len(marketing_customer),4)*100)
marketing_customer = marketing_customer.reset_index()
marketing_customer.columns = ['header_name', 'percent_nulls']

# %%
marketing_customer

# %%
#marketing_customer["effective_to_date"]= pd.to_datetime(marketing_customer["effective_to_date"])

marketing_customer["effective_to_date"] = pd.to_datetime(marketing_customer["effective_to_date"])

# %%
df['Month'] = marketing_customer['"effective_to_date"'].marketing_customer.strftime("%B")

# %%
marketing_customer.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# ## Exercise 2: Structuring Data

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total_claim_amount to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# 3. You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
columns_df= marketing_customer.columns

# %%
columns_df

# %%
# Your code goes here

marketing_customer["sales_channels"]
